# %%
import os
os.chdir("../src")
from run import RunSimulation

# %% [markdown]
# # Individual run analysis

# %%
lanes = 3
length = 2000
spawn = 0.6
agression = 0.5
speed = 130
time_step = 0.1
min_gap = 1.2
test_run = RunSimulation(lanes, length, spawn, agression, speed, time_step, min_gap)

# %%
test_run.run(steps=10000)
# Out:
# 100%|██████████| 10000/10000 [01:08<00:00, 145.72it/s]

# %%
test_run.plot()
